# %%
# !pip install numpy
#Requirement already satisfied:

# %%
import numpy as np
import time

# %%
#execution time differnece
size = 1_000
py_list = list(range(size))
#print(py_list)

start = time.time()
sq_list = [x**2 for x in py_list]
end =  time.time()
print(f"python list time = {end - start} seconds")

np_arr = np.array(py_list)
#print(np_arr)

start = time.time()
sq_arr = np_arr ** 2
end =  time.time()
print(f"numpy array time = {end - start} seconds")
# Out:
# python list time = 0.00039124488830566406 seconds
# numpy array time = 0.0003764629364013672 seconds

# %%
#create with built in functions
arr1 = np.zeros((2,3),dtype = "int64")
print(arr1, arr1.shape)

arr1 = np.ones((5,))
print(arr1, arr1.shape)

arr3 = np.zeros((3,3),100)
print(arr3, arr3.shape)
# Out:
# [[0 0 0]
#  [0 0 0]] (2, 3)
# [1. 1. 1. 1. 1.] (5,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       5 arr1 = np.ones((5,))
#       6 print(arr1, arr1.shape)
# ----> 8 arr3 = np.zeros((3,3),100)
#       9 print(arr3, arr3.shape)
#
# TypeError: Cannot interpret '100' as a data type
