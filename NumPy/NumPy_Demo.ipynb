# %%
# !pip install numpy
#Requirement already satisfied:

# %%
import numpy as np
import time

# %%
#execution time differnece
size = 1_000
py_list = list(range(size))
#print(py_list)

start = time.time()
sq_list = [x**2 for x in py_list]
end =  time.time()
print(f"python list time = {end - start} seconds")

np_arr = np.array(py_list)
#print(np_arr)

start = time.time()
sq_arr = np_arr ** 2
end =  time.time()
print(f"numpy array time = {end - start} seconds")
# Out:
# python list time = 0.0003275871276855469 seconds
# numpy array time = 0.0001499652862548828 seconds

# %%
#create with built in functions
arr1 = np.zeros((2,3),dtype = "int64")
print(arr1, arr1.shape)

arr1 = np.ones((2,3),dtype = "int64")
print(arr1, arr1.shape)
# Out:
# [[0 0 0]
#  [0 0 0]] (2, 3)
# [[1 1 1]
#  [1 1 1]] (2, 3)
