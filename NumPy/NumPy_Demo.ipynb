# %%
# !pip install numpy
#Requirement already satisfied:

# %%
import numpy as np
import time

# %%
#execution time differnece
size = 1_000
py_list = list(range(size))
#print(py_list)

start = time.time()
sq_list = [x**2 for x in py_list]
end =  time.time()
print(f"python list time = {end - start} seconds")

np_arr = np.array(py_list)
#print(np_arr)

start = time.time()
sq_arr = np_arr ** 2
end =  time.time()
print(f"numpy array time = {end - start} seconds")
# Out:
# python list time = 0.00036835670471191406 seconds
# numpy array time = 0.0001537799835205078 seconds

# %%
#create with built in functions
arr1 = np.zeros((2,3),dtype = "int64")
print(arr1, arr1.shape)

arr1 = np.ones((5,))
print(arr1, arr1.shape)

arr3 = np.full((3,3),100)
print(arr3, arr3.shape)

arr4 = np.eye(3)
print(arr4, arr4.shape)

arr5 = np.arange(0,11,2)
print(arr5, arr5.shape)

arr5 = np.linspace(1,100,4)
print(arr5, arr5.shape)
# Out:
# [[0 0 0]
#  [0 0 0]] (2, 3)
# [1. 1. 1. 1. 1.] (5,)
# [[100 100 100]
#  [100 100 100]
#  [100 100 100]] (3, 3)
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]] (3, 3)
# [ 0  2  4  6  8 10] (6,)
# [  1.  34.  67. 100.] (4,)

# %%
#properties
arr = np.array([[1,2,3],[6,4,5]])
print(arr.shape)

reshaped = arr.reshape((3,2))

print(reshaped, reshaped.shape)
flat = arr.flatten()
print(flat, flat.shape)
# Out:
# (2, 3)
# [[1 2]
#  [3 6]
#  [4 5]] (3, 2)
# [1 2 3 6 4 5] (6,)

# %%
#Indexing

arr = np.array([[1,2,3],[6,4,5]])
print(arr.shape)
